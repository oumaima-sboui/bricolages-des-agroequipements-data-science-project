# %% [markdown]
# # instalation and libraries

# %%
#pip install --upgrade google-api-python-client

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyCrEsFkASL6SjyrJE1CikGPkKTyy1z1wYM'
# creating service :get youtube server and raise the request to the  api
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
df = pd.read_csv('info_youtube.csv')
df.columns
df
# Out:
#                                                  title  number_of_views  \
# 0                           Métier de l’Agroéquipement             1072
# 1                               BAC PRO Agroéquipement            53090
# 2                      Les métiers de l'AGROÉQUIPEMENT             1595
# 3    Les risques professionnels en agriculture par ...          2745203
# 4               Présentation du Bac Pro Agroéquipement              129
# ..                                                 ...              ...
# 957                        Apprentissage aux Sardieres              768
# 958                      CAP Agricole Grandes Cultures              447
# 959  Le risque alimentaire est-il sous estimé en Fr...             3051
# 960  Ingéliance, entreprise charentaise spécialisée...              951
# 961  Prendre l’air dans les Jardins du Manoir d’Eyr...              220
#
#      duration                                        description  \
# ...

# %%
df.describe()
# Out:
#        number_of_views     duration
# count     9.620000e+02   962.000000
# mean      1.609136e+04   393.542620
# std       1.896035e+05   887.488004
# min       3.000000e+00    10.000000
# 25%       9.100000e+01   119.000000
# 50%       3.920000e+02   183.000000
# 75%       1.738000e+03   293.000000
# max       3.124930e+06  9309.000000

# %%
channel_ids=df["channel_id"]
lis =[]
for i in pd.unique(df["channel_id"]):
    lis.append(i)
lis[1:50]
# Out:
# ['UC5ulJDk77spJeAwZOLepwwA',
#  'UCdkkxzkWiseC7gEUxZNmT3g',
#  'UC1b8cYXe8t3RGte5JRwBRyQ',
#  'UCQCgBlo8GHImpuS4nj3hBrg',
#  'UCeT9JdLaBOGeO09C78W88-A',
#  'UCsx9RL_-6JW7lQQyFl43xmg',
#  'UCmfgweJ5d5ZzTz9YmlcncLw',
#  'UC7L8oe_qWcjW2tJVpMMLpnQ',
#  'UCAtK9vHZW-7Z7fqFfoiObzQ',
#  'UCxYetAv3l-4fs4eZRZiAHGA',
#  'UCMLLcgMQSlAiLCcBKBMGxTQ',
#  'UCqiJSHUcjlGIHcejo5B1NSA',
#  'UCKpXbgTztfWrrNLx4w1EYKw',
#  'UCV-njQIAL_L1ubn-e2463JA',
#  'UCoUe8r0hse7eal-KzmdkujA',
#  'UCPQazVBeoj3bgRx7pmTzurg',
#  'UCNXeJV9c81QxRWdj3R6cwMA',
#  'UCofpp346LRxvA0STlE5_Giw',
#  'UC-9bMa5FJ6egFk9d-wWfk3w',
#  'UCijjVmjpENHMV9d8B3UYsDg',
#  'UCoxLdW6mTdCsuXE37UVL-XQ',
#  'UCtM9JA5PIRqTajiwcLpphpA',
#  'UCEYzrKNknm8E09wkuwaJbkA',
#  'UCz8zEiifd5oY5OYX5DrOoAg',
#  'UCLiAzcwkwORaixe7msQnBWg',
#  'UCX69NIvGWQb6eKz6BT4Sw4g',
#  'UCRa0O1c29WyDTZLyBjnq6xg',
#  'UC_c5lTT8ZWSe8Is24wSiJvA',
#  'UCBb-9V_cQVP1w-ALMKyWkqw',
#  'UCjJ1A-YVQxrDWrqC1vabrJw',
#  'UCSZL39ZVrg4xcrKuKERisHQ',
#  'UCQvGiofS1gBpvyDgtPzHpRg',
# ...

# %%
n = len(pd.unique(df["channel_id"]))
n
# Out:
# 208

# %%
pd.unique(df["channel_id"])
# Out:
# array(['UCER6IpG62MJgMzdgMhDad2g', 'UC5ulJDk77spJeAwZOLepwwA',
#        'UCdkkxzkWiseC7gEUxZNmT3g', 'UC1b8cYXe8t3RGte5JRwBRyQ',
#        'UCQCgBlo8GHImpuS4nj3hBrg', 'UCeT9JdLaBOGeO09C78W88-A',
#        'UCsx9RL_-6JW7lQQyFl43xmg', 'UCmfgweJ5d5ZzTz9YmlcncLw',
#        'UC7L8oe_qWcjW2tJVpMMLpnQ', 'UCAtK9vHZW-7Z7fqFfoiObzQ',
#        'UCxYetAv3l-4fs4eZRZiAHGA', 'UCMLLcgMQSlAiLCcBKBMGxTQ',
#        'UCqiJSHUcjlGIHcejo5B1NSA', 'UCKpXbgTztfWrrNLx4w1EYKw',
#        'UCV-njQIAL_L1ubn-e2463JA', 'UCoUe8r0hse7eal-KzmdkujA',
#        'UCPQazVBeoj3bgRx7pmTzurg', 'UCNXeJV9c81QxRWdj3R6cwMA',
#        'UCofpp346LRxvA0STlE5_Giw', 'UC-9bMa5FJ6egFk9d-wWfk3w',
#        'UCijjVmjpENHMV9d8B3UYsDg', 'UCoxLdW6mTdCsuXE37UVL-XQ',
#        'UCtM9JA5PIRqTajiwcLpphpA', 'UCEYzrKNknm8E09wkuwaJbkA',
#        'UCz8zEiifd5oY5OYX5DrOoAg', 'UCLiAzcwkwORaixe7msQnBWg',
#        'UCX69NIvGWQb6eKz6BT4Sw4g', 'UCRa0O1c29WyDTZLyBjnq6xg',
#        'UC_c5lTT8ZWSe8Is24wSiJvA', 'UCBb-9V_cQVP1w-ALMKyWkqw',
# ...

# %%
df
# Out:
#                                                  title  number_of_views  \
# 0                           Métier de l’Agroéquipement             1072
# 1                               BAC PRO Agroéquipement            53090
# 2                      Les métiers de l'AGROÉQUIPEMENT             1595
# 3    Les risques professionnels en agriculture par ...          2745203
# 4               Présentation du Bac Pro Agroéquipement              129
# ..                                                 ...              ...
# 957                        Apprentissage aux Sardieres              768
# 958                      CAP Agricole Grandes Cultures              447
# 959  Le risque alimentaire est-il sous estimé en Fr...             3051
# 960  Ingéliance, entreprise charentaise spécialisée...              951
# 961  Prendre l’air dans les Jardins du Manoir d’Eyr...              220
#
#      duration                                        description  \
# ...

# %% [markdown]
# # channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    print (response)
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    channel_id = response['items'][i]['id'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
channel_ids=df.sort_values(by=['number_of_views'], ascending=False)
lis =[]
for i in  (channel_ids["channel_id"]):
    lis.append(i)

# %%
channel_statistics = get_channel_stats(youtube, lis[1:50])
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': 'c7LmkA9tfz1zDOiMrzVWBD9PmlI', 'pageInfo': {'totalResults': 12, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': '3LTpDhDGAoO6B9UsHlHGDWqylqw', 'id': 'UCqiJSHUcjlGIHcejo5B1NSA', 'snippet': {'title': "Ministère de l'Agriculture et de l'Alimentation", 'description': "Chaîne officielle du ministère de l'Agriculture et de l'Alimentation.", 'publishedAt': '2010-11-18T14:06:20Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AKedOLQHmhlskuTWu7A42FvrVXgAQbYyPmDYRZtUI_HD0A=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AKedOLQHmhlskuTWu7A42FvrVXgAQbYyPmDYRZtUI_HD0A=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AKedOLQHmhlskuTWu7A42FvrVXgAQbYyPmDYRZtUI_HD0A=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': "Ministère de l'Agriculture et de l'Alimentation", 'description': 
# ...

# %%
channel_df = pd.DataFrame(channel_statistics)
channel_df
# Out:
#                                          Channel_name Subscribers      Views  \
# 0                         France 3 Nouvelle-Aquitaine      286000  173486104
# 1                             Alex agriculture Vienne       58900   14373688
# 2                                  ALC agroéquipement        2490     690072
# 3                   EmploiMétiers Agriculture - ANEFA        2320    2148796
# 4                  MFR du Périgord Vert, l'Officielle        5920    2807978
# 5                           MFR SAINT ROMAIN DE POPEY         336      61565
# 6                                  Simon. Photography       20600    5682375
# 7     Ministère de l'Agriculture et de l'Alimentation        4950   11335800
# 8                                      Agroequipement          79     100039
# 9   EFEA - L'agriculture de demain est entre vos m...         445      52110
# 10                                   MFR-CFA Chemillé          74     305970
# ...

# %%
channel_df['Subscribers'] = pd.to_numeric(channel_df['Subscribers'])
channel_df['Views'] = pd.to_numeric(channel_df['Views'])
channel_df['Total_videos'] = pd.to_numeric(channel_df['Total_videos'])
channel_df.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# channel_id      object
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
channel_df.columns
# Out:
# Index(['Channel_name', 'Subscribers', 'Views', 'channel_id', 'Total_videos',
#        'playlist_id'],
#       dtype='object')

# %%
df.channel_id.value_counts()
# Out:
# UCmfgweJ5d5ZzTz9YmlcncLw    110
# UCTNpiQT26y_FrXYzbEn0-QQ     88
# UCqtsDi7dt15-zrtSXrlasnQ     50
# UCJ6hqIrCA1qL_yrTd8N6BVA     26
# UCRa0O1c29WyDTZLyBjnq6xg     24
#                            ...
# UCTbfyO6BFtSUpXMc03OgtJA      2
# UCAJdA1bTxw7F29G-Uuh6B3w      2
# UCpdqw5vhIp3WnFfp63_qQ2g      2
# UCHmr3xWLCs5eMt0MCNolJkg      2
# UC5oWzIBclqteQvZg5WDjdKQ      2
# Name: channel_id, Length: 208, dtype: int64

# %% [markdown]
# # More details for video

# %%
import numpy as np
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids[i:i+50]))
        response = request.execute()
        #print(response)
        for video in response['items']:
            if "commentCount" in video['statistics'] :
                Comments = video['statistics']['commentCount']
                
            else :
                Comments = 0
            if   "likeCount" in video['statistics']:
                Likes = video['statistics']['likeCount']
            else :
                Likes = 0
            
       
                 
            
                
            video_stats = dict(Title = video['snippet']['title'],
                               Published_date = video['snippet']['publishedAt'],
                               id = video['id'],
                               Views = video['statistics']['viewCount'],
                               Like = Likes,
                               Comment = Comments
                               )
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_ids=df["id"]
li =[]
for i in (df["id"]):
    li.append(i)

# %%
video_details = get_video_details(youtube, li[1:50])

# %%
video_df = pd.DataFrame(video_details)
video_df
# Out:
#                                                 Title        Published_date  \
# 0                              BAC PRO Agroéquipement  2016-11-04T11:19:05Z
# 1                     Les métiers de l'AGROÉQUIPEMENT  2020-06-03T11:55:38Z
# 2   Les risques professionnels en agriculture par ...  2016-12-16T13:45:27Z
# 3              Présentation du Bac Pro Agroéquipement  2021-01-27T10:39:16Z
# 4   Un été en stage de Bac PRO agroéquipement à la...  2018-09-01T05:34:10Z
# 5                             Filières Agroéquipement  2022-02-03T14:57:19Z
# 6   L' Année 2018 par ALC agroéquipement - BEST OF...  2018-12-29T22:00:00Z
# 7   Porte ouverte MFR IREO - Formation Agroéquipement  2019-03-23T13:00:05Z
# 8             BPA par apprentissage en agroéquipement  2021-01-27T10:27:06Z
# 9   La Filière "Agroéquipement"   - Lycée Agricole...  2022-02-25T15:53:26Z
# 10  Remise L'agroéquipement   la technologie au se...  2021-06-11T12:29:49Z
# ...

# %%
video_df['Like'] = pd.to_numeric(video_df['Like'])

video_df['Views'] = pd.to_numeric(video_df['Views'])
video_df['Comment'] = pd.to_numeric(video_df['Comment'])
video_df.dtypes
# Out:
# Title             object
# Published_date    object
# id                object
# Views              int64
# Like               int64
# Comment            int64
# dtype: object

# %%
top_videos_Views = video_df.sort_values(by='Views', ascending=False)
top_videos_Views
# Out:
#                                                 Title        Published_date  \
# 2   Les risques professionnels en agriculture par ...  2016-12-16T13:45:27Z
# 0                              BAC PRO Agroéquipement  2016-11-04T11:19:05Z
# 36  Les apprentis de BAC PRO AGROEQUIPEMENT chez l...  2017-03-16T13:04:22Z
# 18                    Les métiers de l'agroéquipement  2009-12-17T08:01:29Z
# 4   Un été en stage de Bac PRO agroéquipement à la...  2018-09-01T05:34:10Z
# 7   Porte ouverte MFR IREO - Formation Agroéquipement  2019-03-23T13:00:05Z
# 6   L' Année 2018 par ALC agroéquipement - BEST OF...  2018-12-29T22:00:00Z
# 12                   les métiers de l'agroéquipement.  2018-03-27T15:59:56Z
# 22  L’agroéquipement : des postes à pourvoir chaqu...  2016-05-24T10:06:13Z
# 23  Le Brevet Professionnel Agroéquipement du CFA ...  2021-02-14T13:18:51Z
# 33          Ingénieur en Agroéquipements - UniLaSalle  2017-06-12T08:59:09Z
# ...

# %%
top_videos_Like = video_df.sort_values(by='Like', ascending=False)
top_videos_Like
# Out:
#                                                 Title        Published_date  \
# 2   Les risques professionnels en agriculture par ...  2016-12-16T13:45:27Z
# 0                              BAC PRO Agroéquipement  2016-11-04T11:19:05Z
# 36  Les apprentis de BAC PRO AGROEQUIPEMENT chez l...  2017-03-16T13:04:22Z
# 7   Porte ouverte MFR IREO - Formation Agroéquipement  2019-03-23T13:00:05Z
# 12                   les métiers de l'agroéquipement.  2018-03-27T15:59:56Z
# 4   Un été en stage de Bac PRO agroéquipement à la...  2018-09-01T05:34:10Z
# 23  Le Brevet Professionnel Agroéquipement du CFA ...  2021-02-14T13:18:51Z
# 47  FENDT 942 & CLAAS QUADRANT 5300 FC - Pressage ...  2021-09-05T07:45:09Z
# 6   L' Année 2018 par ALC agroéquipement - BEST OF...  2018-12-29T22:00:00Z
# 11                  Manon : en Bac Pro Agroéquipement  2020-02-20T10:52:57Z
# 13                   BAC Pro Agro-équipement Scolaire  2021-01-28T20:15:07Z
# ...

# %%
video_df['Month'] = pd.to_datetime(video_df['Published_date']).dt.strftime('%b')
video_df
# Out:
#                                                 Title        Published_date  \
# 0                              BAC PRO Agroéquipement  2016-11-04T11:19:05Z
# 1                     Les métiers de l'AGROÉQUIPEMENT  2020-06-03T11:55:38Z
# 2   Les risques professionnels en agriculture par ...  2016-12-16T13:45:27Z
# 3              Présentation du Bac Pro Agroéquipement  2021-01-27T10:39:16Z
# 4   Un été en stage de Bac PRO agroéquipement à la...  2018-09-01T05:34:10Z
# 5                             Filières Agroéquipement  2022-02-03T14:57:19Z
# 6   L' Année 2018 par ALC agroéquipement - BEST OF...  2018-12-29T22:00:00Z
# 7   Porte ouverte MFR IREO - Formation Agroéquipement  2019-03-23T13:00:05Z
# 8             BPA par apprentissage en agroéquipement  2021-01-27T10:27:06Z
# 9   La Filière "Agroéquipement"   - Lycée Agricole...  2022-02-25T15:53:26Z
# 10  Remise L'agroéquipement   la technologie au se...  2021-06-11T12:29:49Z
# ...

# %%
video_df['Year'] = pd.to_datetime(video_df['Published_date']).dt.strftime('%Y')
video_df
# Out:
#                                                 Title        Published_date  \
# 0                              BAC PRO Agroéquipement  2016-11-04T11:19:05Z
# 1                     Les métiers de l'AGROÉQUIPEMENT  2020-06-03T11:55:38Z
# 2   Les risques professionnels en agriculture par ...  2016-12-16T13:45:27Z
# 3              Présentation du Bac Pro Agroéquipement  2021-01-27T10:39:16Z
# 4   Un été en stage de Bac PRO agroéquipement à la...  2018-09-01T05:34:10Z
# 5                             Filières Agroéquipement  2022-02-03T14:57:19Z
# 6   L' Année 2018 par ALC agroéquipement - BEST OF...  2018-12-29T22:00:00Z
# 7   Porte ouverte MFR IREO - Formation Agroéquipement  2019-03-23T13:00:05Z
# 8             BPA par apprentissage en agroéquipement  2021-01-27T10:27:06Z
# 9   La Filière "Agroéquipement"   - Lycée Agricole...  2022-02-25T15:53:26Z
# 10  Remise L'agroéquipement   la technologie au se...  2021-06-11T12:29:49Z
# ...

# %%
videos_per_month = video_df.groupby('Month', as_index=False).size()
videos_per_month.sort_values("size",ascending=False )
# Out:
#    Month  size
# 3    Jan     8
# 6    Mar     8
# 5    Jun     7
# 2    Feb     6
# 7    May     4
# 10   Sep     4
# 0    Apr     3
# 1    Dec     3
# 4    Jul     2
# 8    Nov     2
# 9    Oct     2

# %%
videos_per_Year = video_df.groupby('Year', as_index=False).size()
videos_per_Year.sort_values("size",ascending=False )
# Out:
#     Year  size
# 9   2021    19
# 5   2017     7
# 8   2020     6
# 4   2016     4
# 6   2018     4
# 3   2013     2
# 7   2019     2
# 10  2022     2
# 0   2009     1
# 1   2011     1
# 2   2012     1

# %%
 
Year = sns.barplot(x='Year', y='size', data=videos_per_Year)

# %% [markdown]
# # jointure entre les deux tables (channel_df & df)

# %%
df_jointure=pd.merge(df, channel_df)

# %%
df_jointure
# Out:
#                                                  title  number_of_views  \
# 0                               BAC PRO Agroéquipement            53090
# 1    MFR St Romain, l'agroéquipement des métiers pa...             4706
# 2                               BAC PRO Agroéquipement            53090
# 3    MFR St Romain, l'agroéquipement des métiers pa...             4706
# 4    Les risques professionnels en agriculture par ...          2745203
# ..                                                 ...              ...
# 185  Au lycée agricole de St-Yrieix-la-Perche, un s...          3124930
# 186  Ingéliance, entreprise charentaise spécialisée...              951
# 187  Prendre l’air dans les Jardins du Manoir d’Eyr...              220
# 188                              DynaVT-VarioFendt.wmv            99917
# 189                              DynaVT-VarioFendt.wmv            99917
#
#      duration                                        description  \
# ...

# %%
df_jointure.columns
# Out:
# Index(['title', 'number_of_views', 'duration', 'description', 'publish_date',
#        'author', 'channel_id', 'channel_url', 'keywords', 'id', 'Channel_name',
#        'Subscribers', 'Views', 'Total_videos', 'playlist_id'],
#       dtype='object')

# %%
df_jointure.rename(columns={'number_of_views': 'number_of_views_video', 'Views': 'Views_channel'}, inplace=True)

# %%
df_jointure = df_jointure.drop('author', axis=1)

# %%
df_jointure.columns
# Out:
# Index(['title', 'number_of_views_video', 'duration', 'description',
#        'publish_date', 'channel_id', 'channel_url', 'keywords', 'id',
#        'Channel_name', 'Subscribers', 'Views_channel', 'Total_videos',
#        'playlist_id'],
#       dtype='object')

# %%
df_jointure['Subscribers'] = pd.to_numeric(df_jointure['Subscribers'])
df_jointure['Views_channel'] = pd.to_numeric(df_jointure['Views_channel'])
df_jointure['Total_videos'] = pd.to_numeric(df_jointure['Total_videos'])
df_jointure.dtypes
# Out:
# title                    object
# number_of_views_video     int64
# duration                  int64
# description              object
# publish_date             object
# channel_id               object
# channel_url              object
# keywords                 object
# id                       object
# Channel_name             object
# Subscribers               int64
# Views_channel             int64
# Total_videos              int64
# playlist_id              object
# dtype: object

# %% [raw]
# la chaine avec le  titre et la date video le plus regardée

# %%
pd.pivot_table(df_jointure, index = ['Channel_name','title','publish_date'], values = 'number_of_views_video').sort_values('number_of_views_video', ascending = False)
# Out:
#                                                                                                            number_of_views_video
# Channel_name                       title                                              publish_date
# France 3 Nouvelle-Aquitaine        Au lycée agricole de St-Yrieix-la-Perche, un si... 2018-05-04 00:00:00              3124925.5
# MFR du Périgord Vert, l'Officielle Les risques professionnels en agriculture par T... 2016-12-16 00:00:00              2745208.0
# EmploiMétiers Agriculture - ANEFA  Alexis, 24 ans - conducteur d'engins agricoles     2014-03-25 00:00:00               185274.5
# FRMFR Bretagne                     Présentation du Réseau des MFR de BRETAGNE - fo... 2021-02-10 00:00:00               110442.0
# Agroequipement                     DynaVT-VarioFendt.wmv                              2010-06-29 00:00:00                99917.0
# ...

# %%
pd.pivot_table(df_jointure, index = ['Channel_name','title','publish_date'], values = 'Views_channel').sort_values('Views_channel', ascending = False)
# Out:
#                                                                                                                            Views_channel
# Channel_name                                       title                                              publish_date
# France 3 Nouvelle-Aquitaine                        Prendre l’air dans les Jardins du Manoir d’Eyri... 2022-03-07 00:00:00      173486104
#                                                    Au lycée agricole de St-Yrieix-la-Perche, un si... 2018-05-04 00:00:00      173486104
#                                                    Ingéliance, entreprise charentaise spécialisée ... 2022-03-07 00:00:00      173486104
#                                                    La sécurité enseignée dans les lycées agricoles    2018-05-31 00:00:00      173486104
# Alex agriculture Vienne                            BANC de PUISSANCE et MODULATION de DOSE            2022-03-06 00:00:00       14373688
# ...

# %%
pd.pivot_table(df_jointure, index = ['Channel_name','Subscribers','title'], values = 'number_of_views_video').sort_values('number_of_views_video', ascending = False)
# Out:
#                                                                                                    number_of_views_video
# Channel_name                       Subscribers title
# France 3 Nouvelle-Aquitaine        286000      Au lycée agricole de St-Yrieix-la-Perche, un si...              3124925.5
# MFR du Périgord Vert, l'Officielle 5920        Les risques professionnels en agriculture par T...              2745208.0
# EmploiMétiers Agriculture - ANEFA  2320        Alexis, 24 ans - conducteur d'engins agricoles                   185274.5
# FRMFR Bretagne                     6           Présentation du Réseau des MFR de BRETAGNE - fo...               110442.0
# Agroequipement                     79          DynaVT-VarioFendt.wmv                                             99917.0
# ...                                                                                                                  ...
# ...

# %%
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.barplot(x='Channel_name', y='Subscribers', data=channel_df[:8], hue= 'Channel_name' )
for bar in ax.patches: 
  
    ax.annotate(format(bar.get_height(), '.2f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=15, xytext=(0, 8),textcoords='offset points'
                   )
plt.title("name channel VS  Subscribers") 
plt.show()

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.barplot(x='Channel_name', y='Views', data=channel_df[:8], hue= 'Channel_name' )
for bar in ax.patches: 
  
    ax.annotate(format(bar.get_height(), '.2f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=15, xytext=(0, 8),textcoords='offset points'
                   )
plt.title("name channel VS Views") 
plt.show()

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.barplot(x='Channel_name', y='Total_videos', data=channel_df[:8], hue= 'Channel_name' )
for bar in ax.patches: 
  
    ax.annotate(format(bar.get_height(), '.2f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=15, xytext=(0, 8),textcoords='offset points'
                   )
plt.title("name channel VS Total_videos") 
plt.show()

# %% [markdown]
# # jointure entre les deux tables (video_df & df_jointure)

# %%
df_jointure_final=pd.merge(df_jointure, video_df)
df_jointure_final = df_jointure_final.drop('Title', axis=1)
df_jointure_final = df_jointure_final.drop('publish_date', axis=1)
df_jointure_final = df_jointure_final.drop('Views', axis=1)
df_jointure_final
# Out:
#                                                 title  number_of_views_video  \
# 0                              BAC PRO Agroéquipement                  53090
# 1                              BAC PRO Agroéquipement                  53090
# 2   Les risques professionnels en agriculture par ...                2745203
# 3   Les risques professionnels en agriculture par ...                2745213
# 4   Les apprentis de BAC PRO AGROEQUIPEMENT chez l...                  28493
# 5   Les apprentis de BAC PRO AGROEQUIPEMENT chez l...                  28494
# 6   L' Année 2018 par ALC agroéquipement - BEST OF...                   4121
# 7   L' Année 2018 par ALC agroéquipement - BEST OF...                   4121
# 8   FENDT 942 & CLAAS QUADRANT 5300 FC - Pressage ...                   1985
# 9   FENDT 942 & CLAAS QUADRANT 5300 FC - Pressage ...                   1985
# 10                  Manon : en Bac Pro Agroéquipement                   1395
# ...

# %%
df_jointure_final['Like'] = pd.to_numeric(df_jointure_final['Like'])
df_jointure_final['Comment'] = pd.to_numeric(df_jointure_final['Comment'])

df_jointure_final.dtypes
# Out:
# title                    object
# number_of_views_video     int64
# duration                  int64
# description              object
# channel_id               object
# channel_url              object
# keywords                 object
# id                       object
# Channel_name             object
# Subscribers               int64
# Views_channel             int64
# Total_videos              int64
# playlist_id              object
# Published_date           object
# Like                      int64
# Comment                   int64
# Month                    object
# Year                     object
# dtype: object

# %%
ax = sns.barplot(x='Like', y='title', data=df_jointure_final, hue= 'Channel_name' )

                   
plt.title("title VS like") 
plt.show()

# %%
pd.pivot_table(df_jointure_final, index = ['Channel_name','title','Published_date'], values = 'Like').sort_values('Like', ascending = False)
# Out:
#                                                                                                                          Like
# Channel_name                                    title                                              Published_date
# MFR du Périgord Vert, l'Officielle              Les risques professionnels en agriculture par T... 2016-12-16T13:45:27Z  8775
# MFR SAINT ROMAIN DE POPEY                       BAC PRO Agroéquipement                             2016-11-04T11:19:05Z   415
# MFR du Périgord Vert, l'Officielle              Les apprentis de BAC PRO AGROEQUIPEMENT chez le... 2017-03-16T13:04:22Z   294
# ALC agroéquipement                              FENDT 942 & CLAAS QUADRANT 5300 FC - Pressage d... 2021-09-05T07:45:09Z    66
#                                                 L' Année 2018 par ALC agroéquipement - BEST OF ... 2018-12-29T22:00:00Z    57
# ...

# %%
pd.pivot_table(df_jointure_final, index = ['Channel_name','title','Published_date'], values = 'Like').sort_values('Like', ascending = False)
# Out:
#                                                                                                                          Like
# Channel_name                                    title                                              Published_date
# MFR du Périgord Vert, l'Officielle              Les risques professionnels en agriculture par T... 2016-12-16T13:45:27Z  8775
# MFR SAINT ROMAIN DE POPEY                       BAC PRO Agroéquipement                             2016-11-04T11:19:05Z   415
# MFR du Périgord Vert, l'Officielle              Les apprentis de BAC PRO AGROEQUIPEMENT chez le... 2017-03-16T13:04:22Z   294
# ALC agroéquipement                              FENDT 942 & CLAAS QUADRANT 5300 FC - Pressage d... 2021-09-05T07:45:09Z    66
#                                                 L' Année 2018 par ALC agroéquipement - BEST OF ... 2018-12-29T22:00:00Z    57
# ...

# %%
a=df_jointure_final.groupby(['Channel_name'])['title'].count()
a
# Out:
# Channel_name
# ALC agroéquipement                                 4
# FRMFR Bretagne                                     2
# MFR SAINT ROMAIN DE POPEY                          2
# MFR du Périgord Vert, l'Officielle                 4
# MFR-CFA Chemillé                                   2
# Ministère de l'Agriculture et de l'Alimentation    2
# Name: title, dtype: int64

# %%
a.plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Channel_name'>

# %%
df_jointure_final.columns
# Out:
# Index(['title', 'number_of_views_video', 'duration', 'description',
#        'channel_id', 'channel_url', 'keywords', 'id', 'Channel_name',
#        'Subscribers', 'Views_channel', 'Total_videos', 'playlist_id',
#        'Published_date', 'Like', 'Comment', 'Month', 'Year'],
#       dtype='object')
