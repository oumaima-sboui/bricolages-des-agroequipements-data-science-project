# %% [markdown]
# # YouTube Analysis

# %% [markdown]
# # instalation and libraries

# %%
#pip install --upgrade google-api-python-client

# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
api_key = 'AIzaSyCrEsFkASL6SjyrJE1CikGPkKTyy1z1wYM'
# creating service :get youtube server and raise the request to the  api
youtube = build('youtube', 'v3', developerKey=api_key)

# %%
df = pd.read_csv('info_youtube_2.csv')
df.columns
df
# Out:
#                                                  title  number_of_views  \
# 0    🇸🇪 SUÈDE = L'INCROYABLE AGRICULTURE  ► EP1 ► j...           150473
# 1    Comment faire pousser du canola de bout en bou...             5988
# 2    Les travailleurs coréens qui cueillent des pom...            18498
# 3    Semer du blé d'hiver en solo sur notre ferme d...           150171
# 4    Déchaumeur à disques compact Catros avec pack ...            12376
# ..                                                 ...              ...
# 171  Vlog #130 Épandage d'engrais, comment fonction...            75483
# 172  Processus complet de méthodes de récolte du bl...            15818
# 173  L'empreinte de l'agriculteur : la régénération...            15828
# 174  S2 - E5 : COMMENT CET AGRICULTEUR PRÉSERVE SES...            48948
# 175  Vidéo Vintage 1999 - New Holland Braud VN 240 ...              433
#
#      duration                                        description  \
# ...

# %%
df.describe()
# Out:
#        number_of_views      duration
# count     1.760000e+02    176.000000
# mean      2.334562e+05   1237.937500
# std       9.933511e+05   1276.255622
# min       5.000000e+01     42.000000
# 25%       5.737500e+03    559.250000
# 50%       3.150350e+04    927.000000
# 75%       9.936425e+04   1423.000000
# max       9.198918e+06  10053.000000

# %%
channel_ids=df["channel_id"]
lis =[]
for i in pd.unique(df["channel_id"]):
    lis.append(i)
len(lis)
# Out:
# 89

# %%
n = len(pd.unique(df["channel_id"]))
n
# Out:
# 89

# %%
pd.unique(df["channel_id"])
# Out:
# array(['UCRFQKOcDYYABhmYq4qvkF-g', 'UCYTr93ZqkpdyDh_GTe39bdA',
#        'UCdgwzYpWQhhuSxp6L4P7rmQ', 'UCMR_FIDK1cSU1feDMggF1Gg',
#        'UCFEx_vBope-JV6RhGoDIkaA', 'UC6f1N1Cg__5Ex0aWBUZeYGg',
#        'UCBB0koQM5NI7yoaqGvDhPHQ', 'UCDtqaxFi5Wsjy9PCDjAeeuA',
#        'UCFqLPdQm-k5uCI9gFaxraeA', 'UCe4PVYcuQp1UBeLk2dVXjYQ',
#        'UC1Y0piHYjUlMvR-jT_NonsQ', 'UCTelsVBJ4E2pRv9TXE7zycg',
#        'UClxaaAzHu1B5EoTtBYea7ig', 'UC23kQH-CmMonHHMFVZNrybw',
#        'UCYl9hy6XHWBgrw5aLXVa5dQ', 'UCIaR27VqWf7Xq41Mq3uotXw',
#        'UCegW3qxC77Yrg-nKH-VUMFA', 'UCnBF79nU9DZJchJRkTP9f0w',
#        'UCxeAYuhwAPAsSP7Gtfeml0g', 'UCFF20WbbyKSiYQe0J6a7HTQ',
#        'UCpko_-a4wgz2u_DgDgd9fqA', 'UCXur-8uR91-dEiafZevXwGQ',
#        'UCBiPFRvV4zLgiUSoh-gABTg', 'UCORoPcG1W1bLl1ya5tNk-mQ',
#        'UCnnF1-A2Uacfv7D361QNJ5g', 'UCPURNskhAqEaRFG2lFNuhZg',
#        'UC5ezxE4niL1BIIOeMf3zvtg', 'UCE8VsQ9GFj3WqA7F_yKrL2w',
#        'UCp0EDcHAOofwbz-jLLStWgQ', 'UCD2DbJnKu7pTLRNd0bsUopA',
# ...

# %% [markdown]
# # channel statistics

# %%
def get_channel_stats(youtube, channel_ids):
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                
                id=','.join(channel_ids), maxResults = 50)
    response = request.execute() 
    
    print (response)
    for i in range(len(response['items'])):
        data = dict(Channel_name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    channel_id = response['items'][i]['id'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return all_data

# %%
#channel_ids=df.sort_values(by=['number_of_views'], ascending=False)
lis =[]
for i in  (df["channel_id"]):
    lis.append(i)
    
len(lis)
# Out:
# 176

# %%
channel_statistics = get_channel_stats(youtube, lis[0:50])

channel_statistics_1 = get_channel_stats(youtube, lis[51:100])

channel_statistics_2 = get_channel_stats(youtube, lis[101:150])

channel_statistics_3 = get_channel_stats(youtube, lis[151:])
print("****************",len(channel_statistics_1))
print("****************",len(channel_statistics_2))
print("****************",len(channel_statistics))
print(len(channel_statistics_3))
# Out:
# {'kind': 'youtube#channelListResponse', 'etag': '9CFVY3i2hhu4zGV4xozwSJL59NE', 'pageInfo': {'totalResults': 34, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#channel', 'etag': 'R7O_Juwxq5QDgh7P_NrmgP9Q8Gs', 'id': 'UC_hQjd17rrWhzWe0FSDzVtg', 'snippet': {'title': 'Mathieu Pung', 'description': '', 'publishedAt': '2014-08-14T08:33:51Z', 'thumbnails': {'default': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8J6ubE4yOLY5RDjZphOzXAbXbDMso7cpLGhmfJzw=s88-c-k-c0x00ffffff-no-rj', 'width': 88, 'height': 88}, 'medium': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8J6ubE4yOLY5RDjZphOzXAbXbDMso7cpLGhmfJzw=s240-c-k-c0x00ffffff-no-rj', 'width': 240, 'height': 240}, 'high': {'url': 'https://yt3.ggpht.com/ytc/AMLnZu8J6ubE4yOLY5RDjZphOzXAbXbDMso7cpLGhmfJzw=s800-c-k-c0x00ffffff-no-rj', 'width': 800, 'height': 800}}, 'localized': {'title': 'Mathieu Pung', 'description': ''}}, 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UU_hQjd17rrWhzWe0FSDzVtg'}}, 'statistics': {'viewCount': '9358', 's
# ...

# %%
channel_df = pd.DataFrame(channel_statistics)
channel_df1= pd.DataFrame(channel_statistics_1)
channel_df2= pd.DataFrame(channel_statistics_2)
channel_df3= pd.DataFrame(channel_statistics_3)

# %%
ch=pd.concat([channel_df, channel_df1,channel_df2,channel_df3])

# %%
ch['Subscribers'] = pd.to_numeric(ch['Subscribers'])
ch['Views'] = pd.to_numeric(ch['Views'])
ch['Total_videos'] = pd.to_numeric(ch['Total_videos'])
ch.dtypes
# Out:
# Channel_name    object
# Subscribers      int64
# Views            int64
# channel_id      object
# Total_videos     int64
# playlist_id     object
# dtype: object

# %%
channel_df.columns
# Out:
# Index(['Channel_name', 'Subscribers', 'Views', 'channel_id', 'Total_videos',
#        'playlist_id'],
#       dtype='object')

# %%
df.channel_id.value_counts()
# Out:
# UCMR_FIDK1cSU1feDMggF1Gg    33
# UCDtqaxFi5Wsjy9PCDjAeeuA    15
# UCYTr93ZqkpdyDh_GTe39bdA    10
# UCRFQKOcDYYABhmYq4qvkF-g     6
# UC2eQ4aykXXaYdZwhw1GWVIQ     6
#                             ..
# UCuVtsYzsdU4sDQ7atH4Ed-Q     1
# UCpMazsY8fz2IH0FiLB0_Ugw     1
# UCFxJzl5uVPd9qpHJC04LYGg     1
# UCE8VsQ9GFj3WqA7F_yKrL2w     1
# UCZdAJQWIhuLkAx0VZ2mMaFg     1
# Name: channel_id, Length: 89, dtype: int64

# %% [markdown]
# # More details for video

# %%
import numpy as np
def get_video_details(youtube, video_ids):
    all_video_stats = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
                    part='snippet,statistics',
                    id=','.join(video_ids),
                 
                    )
        response = request.execute()
        #print(response)
        for video in response['items']:
            if "commentCount" in video['statistics'] :
                Comments = video['statistics']['commentCount']
                
            else :
                Comments = 0
            if   "likeCount" in video['statistics']:
                Likes = video['statistics']['likeCount']
            else :
                Likes = 0
            
       
                 
            
                
            video_stats = dict(Title = video['snippet']['title'],
                               
                               Published_date = video['snippet']['publishedAt'],
                               id = video['id'],
                               Views = video['statistics']['viewCount'],
                               Like = Likes,
                               Comment = Comments
                               )
           
            all_video_stats.append(video_stats)
    
    return all_video_stats

# %%
video_ids=df["id"]
li =[]
for i in (df["id"]):
    li.append(i)

# %%
video_details = get_video_details(youtube, li[0:50])
video_details_1 = get_video_details(youtube, li[51:100])
video_details_2 = get_video_details(youtube, li[101:150])
video_details_3 = get_video_details(youtube, li[151:])

# %%
video_df = pd.DataFrame(video_details)
video_df_1 = pd.DataFrame(video_details_1)
video_df_2 = pd.DataFrame(video_details_3)
video_df_3 = pd.DataFrame(video_details_3)

# %%
v=pd.concat([video_df, video_df_1,video_df_2,video_df_3])
v.drop(v.loc[v['id']=='6janW0h3cZY'].index, inplace=True)
v.drop(v.loc[v['duration']== 10053].index, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\users\lenovo\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'duration'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
v['Like'] = pd.to_numeric(v['Like'])

v['Views'] = pd.to_numeric(v['Views'])
v['Comment'] = pd.to_numeric(v['Comment'])
v.dtypes
# Out:
# Title             object
# Published_date    object
# id                object
# Views              int64
# Like               int64
# Comment            int64
# dtype: object

# %%
top_videos_Views = v.sort_values(by='Views', ascending=False)
top_videos_Views
# Out:
#                                                 Title        Published_date  \
# 32  I Only Ate Food That I Grew Or Foraged For One...  2020-01-28T19:00:07Z
# 48           Why we love, why we cheat | Helen Fisher  2007-01-16T18:20:55Z
# 23  First Day of Swathing Wheat 2022!  Montana Har...  2022-07-27T16:15:01Z
# 16  SIEGA, TRILLA y transporte tradicional de la p...  2021-02-11T23:00:04Z
# 16  SIEGA, TRILLA y transporte tradicional de la p...  2021-02-11T23:00:04Z
# ..                                                ...                   ...
# 30                       Animal Farm by George Orwell  2021-07-19T05:14:59Z
# 16  Tecnologia embarcada na colhedora de cana-de-a...  2021-12-14T23:46:56Z
# 46  Point of No Return. U.N. #1 critical global is...  2022-03-14T17:56:16Z
# 3                      5.4 Credit and Risk in Farming  2014-08-16T21:12:41Z
# 3                      5.4 Credit and Risk in Farming  2014-08-16T21:12:41Z
#
#              id    Views    Like  Comment
# ...

# %%
top_videos_Like = v.sort_values(by='Like', ascending=False)
top_videos_Like
# Out:
#                                                 Title        Published_date  \
# 32  I Only Ate Food That I Grew Or Foraged For One...  2020-01-28T19:00:07Z
# 48           Why we love, why we cheat | Helen Fisher  2007-01-16T18:20:55Z
# 1               Tools and techniques: no dig bed prep  2020-11-09T06:12:06Z
# 43  Disaster!! Digging Out Dirt & Last Day of Harv...  2021-10-07T22:22:20Z
# 16  SIEGA, TRILLA y transporte tradicional de la p...  2021-02-11T23:00:04Z
# ..                                                ...                   ...
# 13         Harvest Setup on a John Deere 9770 Combine  2019-09-17T14:02:11Z
# 13         Harvest Setup on a John Deere 9770 Combine  2019-09-17T14:02:11Z
# 3                      5.4 Credit and Risk in Farming  2014-08-16T21:12:41Z
# 3                      5.4 Credit and Risk in Farming  2014-08-16T21:12:41Z
# 14                  Le glyphosate au coeur des champs  2020-12-27T13:30:02Z
#
#              id    Views    Like  Comment
# ...

# %%
v['Month'] = pd.to_datetime(v['Published_date']).dt.strftime('%b')
v

# %%
 
Year = sns.barplot(x='Year', y='size', data=videos_per_Year)

# %%
videos_per_month = v.groupby('Month', as_index=False).size()
videos_per_month.sort_values("size",ascending=False )

# %%
 
Month= sns.barplot(x='Month', y='size', data=videos_per_month)

# %%
videos_per_Year = v.groupby('Year', as_index=False).size()
videos_per_Year.sort_values("size",ascending=False )

# %%
 
Year = sns.barplot(x='Year', y='size', data=videos_per_Year)

# %% [markdown]
# # jointure entre les deux tables (channel_df & df)

# %%
df_jointure=pd.merge(df, ch)

# %%
df_jointure
# Out:
#                                                  title  number_of_views  \
# 0    🇸🇪 SUÈDE = L'INCROYABLE AGRICULTURE  ► EP1 ► j...           150473
# 1    🇸🇪 SUÈDE = L'INCROYABLE AGRICULTURE  ► EP1 ► j...           150473
# 2    🇸🇪 SUÈDE = L'INCROYABLE AGRICULTURE  ► EP1 ► j...           150473
# 3    L'équipe de foin chez ETA JAMES : Départ de l'...           220662
# 4    L'équipe de foin chez ETA JAMES : Départ de l'...           220662
# ..                                                 ...              ...
# 406  CTI : Idéalistes avec une approche pragmatique...             1285
# 407  Faire de l'agriculture un jeu, pourquoi la rév...             7522
# 408  Processus complet de méthodes de récolte du bl...            15818
# 409  L'empreinte de l'agriculteur : la régénération...            15828
# 410  Vidéo Vintage 1999 - New Holland Braud VN 240 ...              433
#
#      duration                                        description  \
# ...

# %%
df_jointure.columns
# Out:
# Index(['title', 'number_of_views', 'duration', 'description', 'publish_date',
#        'author', 'channel_id', 'channel_url', 'keywords', 'id', 'Channel_name',
#        'Subscribers', 'Views', 'Total_videos', 'playlist_id'],
#       dtype='object')

# %%
df_jointure.rename(columns={'number_of_views': 'number_of_views_video', 'Views': 'Views_channel'}, inplace=True)

# %%
df_jointure = df_jointure.drop('author', axis=1)

# %%
df_jointure.columns
# Out:
# Index(['title', 'number_of_views_video', 'duration', 'description',
#        'publish_date', 'channel_id', 'channel_url', 'keywords', 'id',
#        'Channel_name', 'Subscribers', 'Views_channel', 'Total_videos',
#        'playlist_id'],
#       dtype='object')

# %%
df_jointure['Subscribers'] = pd.to_numeric(df_jointure['Subscribers'])
df_jointure['Views_channel'] = pd.to_numeric(df_jointure['Views_channel'])
df_jointure['Total_videos'] = pd.to_numeric(df_jointure['Total_videos'])
df_jointure.dtypes
# Out:
# title                    object
# number_of_views_video     int64
# duration                  int64
# description              object
# publish_date             object
# channel_id               object
# channel_url              object
# keywords                 object
# id                       object
# Channel_name             object
# Subscribers               int64
# Views_channel             int64
# Total_videos              int64
# playlist_id              object
# dtype: object

# %% [raw]
# la chaine avec le  titre et la date video le plus regardée

# %%
pd.pivot_table(df_jointure, index = ['Channel_name','title','publish_date'], values = 'number_of_views_video').sort_values('number_of_views_video', ascending = False)
# Out:
#                                                                                                                   number_of_views_video
# Channel_name                              title                                              publish_date
# Jesus Film                                JÉSUS ► Anglais (bn-BD) 🎬 Film complet officiel... 2018-10-09 00:00:00              9198918.0
# Investigations et Enquêtes                Gitans contre Mairie :  Une tension permanente     2018-06-19 00:00:00              8045998.0
# Soil Health Institute                     Film de sol vivant                                 2018-11-15 00:00:00              3824187.0
# BuzzFeedVideo                             Je n'ai mangé que de la nourriture que j'ai cul... 2020-01-28 00:00:00              3057150.0
# TED                                       Pourquoi nous aimons, pourquoi nous trompons He... 2007-01-16 00:00:00              1632705.0
# ...

# %%
pd.pivot_table(df_jointure, index = ['Channel_name','title','publish_date'], values = 'Views_channel').sort_values('Views_channel', ascending = False)
# Out:
#                                                                                                    Views_channel
# Channel_name               title                                              publish_date
# BuzzFeedVideo              Je n'ai mangé que de la nourriture que j'ai cul... 2020-01-28 00:00:00    17769249700
# TED                        Pourquoi nous aimons, pourquoi nous trompons He... 2007-01-16 00:00:00     2382944332
# Investigations et Enquêtes Gitans contre Mairie :  Une tension permanente     2018-06-19 00:00:00      664805216
# AgrarBlick                 Récolte de colza 2021 dans la moissonneuse-batt... 2021-07-25 00:00:00      428918555
# hrfernsehen                Deux entreprises familiales entre tradition et ... 2021-04-29 00:00:00      294802657
# ...                                                                                                          ...
# ...

# %%
pd.pivot_table(df_jointure, index = ['Channel_name','Subscribers','title'], values = 'number_of_views_video').sort_values('number_of_views_video', ascending = False)
# Out:
#                                                                                                           number_of_views_video
# Channel_name                              Subscribers title
# Jesus Film                                1380000     JÉSUS ► Anglais (bn-BD) 🎬 Film complet officiel...              9198918.0
# Investigations et Enquêtes                2030000     Gitans contre Mairie :  Une tension permanente                  8045998.0
# Soil Health Institute                     27200       Film de sol vivant                                              3824187.0
# BuzzFeedVideo                             20300000    Je n'ai mangé que de la nourriture que j'ai cul...              3057150.0
# TED                                       21800000    Pourquoi nous aimons, pourquoi nous trompons He...              1632705.0
# ...                                                                                                                         ...
# ...

# %%
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(25,20)})
ch.drop(ch.loc[ch['Channel_name']=='Stauffer Garage'].index, inplace=True)
ax = sns.barplot(x='Channel_name', y='Subscribers', data=ch[:8], hue= 'Channel_name' )
for bar in ax.patches: 
  
    ax.annotate(format(bar.get_height(), '.2f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=15, xytext=(0, 8),textcoords='offset points'
                   )
plt.title("name channel VS  Subscribers") 
plt.show()

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.barplot(x='Channel_name', y='Views', data=ch[:8], hue= 'Channel_name' )
for bar in ax.patches: 
  
    ax.annotate(format(bar.get_height(), '.2f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=15, xytext=(0, 8),textcoords='offset points'
                   )
plt.title("name channel VS Views") 
plt.show()

# %%
sns.set(rc={'figure.figsize':(25,20)})
ax = sns.barplot(x='Channel_name', y='Total_videos', data=ch[:8], hue= 'Channel_name' )
for bar in ax.patches: 
  
    ax.annotate(format(bar.get_height(), '.2f'),  
                   (bar.get_x() + bar.get_width() / 2,  
                    bar.get_height()), ha='center', va='center', 
                   size=15, xytext=(0, 8),textcoords='offset points'
                   )
plt.title("name channel VS Total_videos") 
plt.show()

# %% [markdown]
# # jointure entre les deux tables (video_df & df_jointure)

# %%
df_jointure_final=pd.merge(df_jointure, v)
df_jointure_final = df_jointure_final.drop('Title', axis=1)
df_jointure_final = df_jointure_final.drop('publish_date', axis=1)
df_jointure_final = df_jointure_final.drop('Views', axis=1)
df_jointure_final
# Out:
#                                                  title  number_of_views_video  \
# 0    🇸🇪 SUÈDE = L'INCROYABLE AGRICULTURE  ► EP1 ► j...                 150473
# 1    🇸🇪 SUÈDE = L'INCROYABLE AGRICULTURE  ► EP1 ► j...                 150473
# 2    🇸🇪 SUÈDE = L'INCROYABLE AGRICULTURE  ► EP1 ► j...                 150473
# 3    L'équipe de foin chez ETA JAMES : Départ de l'...                 220662
# 4    L'équipe de foin chez ETA JAMES : Départ de l'...                 220662
# ..                                                 ...                    ...
# 324  Processus complet de méthodes de récolte du bl...                  15818
# 325  L'empreinte de l'agriculteur : la régénération...                  15828
# 326  L'empreinte de l'agriculteur : la régénération...                  15828
# 327  Vidéo Vintage 1999 - New Holland Braud VN 240 ...                    433
# 328  Vidéo Vintage 1999 - New Holland Braud VN 240 ...                    433
#
# ...

# %%
df_jointure_final['Like'] = pd.to_numeric(df_jointure_final['Like'])
df_jointure_final['Comment'] = pd.to_numeric(df_jointure_final['Comment'])

df_jointure_final.dtypes
# Out:
# title                    object
# number_of_views_video     int64
# duration                  int64
# description              object
# channel_id               object
# channel_url              object
# keywords                 object
# id                       object
# Channel_name             object
# Subscribers               int64
# Views_channel             int64
# Total_videos              int64
# playlist_id              object
# Published_date           object
# Like                      int64
# Comment                   int64
# dtype: object

# %%
  
df_jointure_final.to_csv('info_youTube_final.csv', sep =',')

# %%
exemple=pd.pivot_table(df_jointure_final, index = ['Channel_name','title','Published_date'], values = 'Like').sort_values('Like', ascending = False)

# %%
pd.pivot_table(df_jointure_final, index = ['Channel_name','title','Published_date'], values = 'Like').sort_values('Published_date', ascending = False)
# Out:
#                                                                                                                             Like
# Channel_name                                      title                                              Published_date
# NEW HOLLAND BRAUD - Grape Harvester Excellence    Vidéo Vintage 1999 - New Holland Braud VN 240 e... 2022-08-11T17:00:07Z     13
# Landwirt_in_MV                                    Vlog #154 A quoi ressemble l'entretien quotidie... 2022-08-07T09:00:04Z   3925
# Kate's Ag - Farm to Fashion                       Premier jour d'andainage du blé Récolte du Mont... 2022-07-27T16:15:01Z   5286
# Rừng Và Tôi                                       Construire une nouvelle vie épisode 51 Maman no... 2022-07-14T11:30:21Z   1327
# DauHan Jadoo                                      Les travailleurs coréens qui cueillent des pomm... 2022-07-14T05:19:17Z    416
# ...

# %%
pd.pivot_table(df_jointure_final, index = ['Channel_name','title','Published_date',"duration"], values = 'Like').sort_values('duration', ascending = False)
# Out:
#                                                                                                                                      Like
# Channel_name                                       title                                              Published_date       duration
# Classic Masterworks                                La ferme des animaux de George Orwell              2021-07-19T05:14:59Z 10053        5
# Agronomia UNIFATECIE                               Technologie embarquée dans la récolteuse de can... 2021-12-14T23:46:56Z 4208        10
# USDA NRCS East National Technology Support Center  Gestion des cultures de couverture pour la gest... 2012-09-11T16:11:39Z 3853        31
# Dr Eric Brennan USDA-ARS                           Comment fabriquer le semoir à marteau coulissant   2019-01-16T06:26:22Z 3657       144
# IRDA                                               Le Farming Systems Trial du Rodale Institut        2015-05-13T19:17:29Z 3305        12
# ...

# %%
a=df_jointure_final.groupby(['Channel_name'])['title'].count()
a

# %%
a.plot(kind = 'bar')

# %%
df_jointure_final.columns

# %%
df_jointure_final.to_csv('info_youTube_final.csv', encoding ="utf-8-sig",sep =',')
